# %%
# Importação de bibliotecas externas necessárias
import sys
import os
import cProfile as cpr
from pyprof2calltree import convert

sys.path.append(os.path.abspath("../..")) 


import logging
from Modules.Models import * 
from Modules.Methods import *
from Modules.Handlers import *
from datetime import datetime



string_data = datetime.now().strftime("%d_%m_%Y_%H_%M")
# Out:
# c:\Users\Pedro\faculdade\IniciacaoCientifica\grn\PythonCode\Modules\Methods.py:89: SyntaxWarning: 'return' in a 'finally' block
#   return result_data

# %%
gen=20
handler = ExecutionHandler(
    model=ModelWrapper.GRN5(train_percentage=1.0),              #"configures" the "model-object", to be ready to use
    method_class=DE,
    seeds=[0],
    solvers=['ODEINT'],
    errors=['MSE'],
    generations=gen,
    parallel=False,
)

handler
# Out:
# <ExecutionHandler Configuration>
# { 'Additional Params': {},
#   'Errors': ['MSE'],
#   'Generations': 20,
#   'Method Name': 'DE',
#   'Model Name': 'GRN5',
#   'Output Directory': '../../Outputs/',
#   'Parallel Execution': False,
#   'Seeds': [0],
#   'Solvers': ['ODEINT'],
#   'train_percentage': 1.0}

# %%
#if __name__ == "__main__":    #garantees that the code will be profilled when ran, not imported
with cpr.Profile() as profile: #runs everything inside the block using the Profile()
        handler.execute()

callgrind_filename = f"callgrind.{string_data}_GRN5_DE_Parallel_{gen}_generations_results.out"
convert(profile.getstats(), callgrind_filename)
print(f"Profiling complete! Open QCacheGrind and load: {callgrind_filename}")
# Out:
# Starting execution with ID: GRN5_DE_SERIAL_20260826_162630
# Running with seed=0, solver=ODEINT, error=MSE
# setando seed: 0
# c:\Users\Pedro\faculdade\IniciacaoCientifica\grn\.env\Lib\site-packages\scipy\optimize\_differentialevolution.py:518: UserWarning: differential_evolution: the 'vectorized' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# differential_evolution step 1: f(x)= 0.2563115466401003
# Polishing solution with 'L-BFGS-B'
# Profiling complete! Open QCacheGrind and load: callgrind.26_08_2026_16_26_GRN5_DE_Parallel_20_generations_results.out
