# %%
import cProfile as cpr
import re


import matrix as ma

# %%
k=500

cpr.run('re.compile("foo|bar")')
m1 = ma.criar(k)
m2= ma.criar(k)

m3= ma.multiplicar(m1,m2)
# Out:
#          220 function calls (213 primitive calls) in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 __init__.py:287(compile)
#         1    0.000    0.000    0.000    0.000 __init__.py:330(_compile)
#         1    0.000    0.000    0.000    0.000 _compiler.py:221(_compile_charset)
#         1    0.000    0.000    0.000    0.000 _compiler.py:248(_optimize_charset)
#       3/1    0.000    0.000    0.000    0.000 _compiler.py:39(_compile)
#         2    0.000    0.000    0.000    0.000 _compiler.py:442(_get_iscased)
#         1    0.000    0.000    0.000    0.000 _compiler.py:450(_get_literal_prefix)
#         1    0.000    0.000    0.000    0.000 _compiler.py:481(_get_charset_prefix)
#         1    0.000    0.000    0.000    0.000 _compiler.py:525(_compile_info)
# ...
